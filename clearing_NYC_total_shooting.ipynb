# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("NYPD_Shooting_Incident_Data__Historic_.csv")

# %%
data.head()
# Out:
#    INCIDENT_KEY              OCCUR_DATE OCCUR_TIME           BORO  PRECINCT  \
# 0     169180023  09/09/2017 12:00:00 AM    3:57:00  STATEN ISLAND       120
# 1     169180027  09/09/2017 12:00:00 AM   22:15:00          BRONX        50
# 2     169180025  09/09/2017 12:00:00 AM   18:35:00       BROOKLYN        79
# 3     169180024  09/09/2017 12:00:00 AM   15:20:00       BROOKLYN        67
# 4     169180022  09/09/2017 12:00:00 AM    0:20:00       BROOKLYN        61
#
#    JURISDICTION_CODE              LOCATION_DESC  STATISTICAL_MURDER_FLAG  \
# 0                0.0                        NaN                    False
# 1                0.0                        NaN                    False
# 2                2.0  MULTI DWELL - PUBLIC HOUS                    False
# 3                0.0                        NaN                    False
# 4                2.0  MULTI DWELL - PUBLIC HOUS                    False
#
#   PERP_AGE_GROUP PERP_SEX PERP_RACE VIC_AGE_GROUP VIC_SEX  \
# ...

# %%
data_econ = pd.read_excel('econ.xlsx')

# %%
data_econ.head()
# Out:
#    GeoType          GeogName GeoID   Borough  Pop16plE  Pop16plM  Pop16plC  \
# 0  NTA2010        Bath Beach  BK27  Brooklyn     26855     943.0       2.1
# 1  NTA2010         Bay Ridge  BK31  Brooklyn     65479    1260.0       1.2
# 2  NTA2010           Bedford  BK75  Brooklyn     54904    1390.0       1.5
# 3  NTA2010  Bensonhurst East  BK29  Brooklyn     52857    1307.0       1.5
# 4  NTA2010  Bensonhurst West  BK28  Brooklyn     74470    1568.0       1.3
#
#    Pop16plP  Pop16plZ    LFE    ...     Pv400t499E  Pv400t499M  Pv400t499C  \
# 0     100.0       NaN  16006    ...           3464       434.0         7.6
# 1     100.0       NaN  42176    ...           7564       572.0         4.6
# 2     100.0       NaN  36993    ...           5175       561.0         6.6
# 3     100.0       NaN  32004    ...           5634       522.0         5.6
# 4     100.0       NaN  45842    ...           7969       641.0         4.9
#
# ...

# %%
new_data_econ = data_econ[['GeogName','Borough','CvEm16pl1E','CvEm16pl1P','CvLFUEm1E','CvLFUEm1P', 'MdHHIncE']]

# %%
new_data_econ.rename(columns ={'CvEm16pl1E':'Employed',
                               'CvEm16pl1P':'Employed_%',
                               'CvLFUEm1E':'Unemployed',
                               'CvLFUEm1P':'Unemployed_%',
                               'MdHHIncE':'Median_income'
                              })
# Out:
#                                              GeogName    Borough  Employed  \
# 0                                          Bath Beach   Brooklyn     14857
# 1                                           Bay Ridge   Brooklyn     38906
# 2                                             Bedford   Brooklyn     32339
# 3                                    Bensonhurst East   Brooklyn     29258
# 4                                    Bensonhurst West   Brooklyn     41784
# 5                                        Borough Park   Brooklyn     36796
# 6                                      Brighton Beach   Brooklyn     14116
# 7                        Brooklyn Heights-Cobble Hill   Brooklyn     13873
# 8                                         Brownsville   Brooklyn     19893
# 9                                      Bushwick North   Brooklyn     30751
# 10                                     Bushwick South   Brooklyn     35371
# ...

# %%
df_econ = new_data_econ.iloc[:-1, :]
df_econ.rename(columns ={'CvEm16pl1E':'Employed',
                               'CvEm16pl1P':'Employed_%',
                               'CvLFUEm1E':'Unemployed',
                               'CvLFUEm1P':'Unemployed_%',
                               'MdHHIncE':'Median_income'
                              }, inplace=True)

# %%
df_econ.to_csv(r'NYC_econ2.csv')

# %%
df_econ.to_excel(r'NYC_econ_excel.xlsx')

# %%
new_econ = pd.read_excel("NYC_econ_NTA_pd.xlsx")

# %%
new_econ.to_csv(r'NYC_econ_NTA_pd.csv')

# %%
data_NTA_Pdistrict = pd.read_csv("NTA_POLICE_DISTRICT_NYC.csv")

# %%
data_NTA_Pdistrict.head()
# Out:
#    CB2010  BoroCode       BoroName  CT2010    BCTCB2010  BoroCT2010  \
# 0    1000         5  Staten Island     900  50009001000     5000300
# 1    1000         5  Staten Island    2001  50020011000     5003600
# 2    1000         5  Staten Island    2700  50027001000     5002100
# 3    1000         5  Staten Island    4000  50040001000     5004000
# 4    1000         5  Staten Island    6400  50064001000     5005000
#
#   CDEligibil NTACode                                    NTAName  PUMA  \
# 0          I    SI22  West New Brighton-New Brighton-St. George  3903
# 1          I    SI37                         Stapleton-Rosebank  3903
# 2          E    SI37                         Stapleton-Rosebank  3903
# 3          E    SI08              Grymes Hill-Clifton-Fox Hills  3903
# 4          I    SI14            Grasmere-Arrochar-Ft. Wadsworth  3902
#
#      ...     HealthArea  HCentDist  Precinct  SchoolDist  StSenDist  CongDist  \
# ...

# %%
type(data_NTA_Pdistrict)
# Out:
# pandas.core.frame.DataFrame

# %%
data_NTA_Pdistrict_new = data_NTA_Pdistrict[['NTAName','Precinct']]

# %%
data_NTA_Pdistrict_new
# Out:
#                                                  NTAName  Precinct
# 0              West New Brighton-New Brighton-St. George       120
# 1                                     Stapleton-Rosebank       120
# 2                                     Stapleton-Rosebank       120
# 3                          Grymes Hill-Clifton-Fox Hills       120
# 4                        Grasmere-Arrochar-Ft. Wadsworth       122
# 5                        Grasmere-Arrochar-Ft. Wadsworth       122
# 6              West New Brighton-New Brighton-St. George       120
# 7              West New Brighton-New Brighton-St. George       120
# 8                      Old Town-Dongan Hills-South Beach       122
# 9                      Old Town-Dongan Hills-South Beach       122
# 10                     Old Town-Dongan Hills-South Beach       122
# 11                                New Dorp-Midland Beach       122
# 12                              New Brighton-Silver Lake       120
# ...

# %%
data_NTA_Pdistrict_new_new = data_NTA_Pdistrict.groupby(['Precinct','NTAName']).size()

# %%
data_NTA_Pdistrict_new_new
# Out:
# Precinct  NTAName
# 1         Battery Park City-Lower Manhattan                           188
#           Chinatown                                                    11
#           SoHo-TriBeCa-Civic Center-Little Italy                      193
#           West Village                                                 23
#           park-cemetery-etc-Manhattan                                  39
# 5         Chinatown                                                   130
#           SoHo-TriBeCa-Civic Center-Little Italy                       49
# 6         Hudson Yards-Chelsea-Flatiron-Union Square                    5
#           West Village                                                175
# 7         Chinatown                                                    58
#           East Village                                                  1
#           Lower East Side                                             132
# ...

# %%
data_NTA_Pdistrict_DataFrame = data_NTA_Pdistrict_new_new.to_frame()
data_NTA_Pdistrict_DataFrame
# Out:
#                                                                0
# Precinct NTAName
# 1        Battery Park City-Lower Manhattan                   188
#          Chinatown                                            11
#          SoHo-TriBeCa-Civic Center-Little Italy              193
#          West Village                                         23
#          park-cemetery-etc-Manhattan                          39
# 5        Chinatown                                           130
#          SoHo-TriBeCa-Civic Center-Little Italy               49
# 6        Hudson Yards-Chelsea-Flatiron-Union Square            5
#          West Village                                        175
# 7        Chinatown                                            58
#          East Village                                          1
#          Lower East Side                                     132
# 9        East Village                                         53
# ...

# %%
type(data_NTA_Pdistrict_DataFrame)
# Out:
# pandas.core.frame.DataFrame

# %%
df_NTA_Pd = data_NTA_Pdistrict_DataFrame.iloc[:, :-1]

# %%
df_NTA_Pd
# Out:
# Empty DataFrame
# Columns: []
# ...

# %%
df_NTA_Pd.to_excel(r'NYC_NTA_Pdistrict2.xlsx')

# %%
df_NTA_Pd.to_csv(r'NYC_NTA_Pdistrict2.csv')

# %%
data_NTA_Pdistrict_new.drop_duplicates(['NTAName']).count()
# Out:
# NTAName     195
# Precinct    195
# dtype: int64

# %%
data_NTA_Pdistrict_new.drop_duplicates(['Precinct']).count()
# Out:
# NTAName     77
# Precinct    77
# dtype: int64

# %%
data_NTA_Pdistrict_new.drop_duplicates(['NTAName'])
# Out:
#                                                  NTAName  Precinct
# 0              West New Brighton-New Brighton-St. George       120
# 1                                     Stapleton-Rosebank       120
# 3                          Grymes Hill-Clifton-Fox Hills       120
# 4                        Grasmere-Arrochar-Ft. Wadsworth       122
# 8                      Old Town-Dongan Hills-South Beach       122
# 11                                New Dorp-Midland Beach       122
# 12                              New Brighton-Silver Lake       120
# 15                                 Oakwood-Oakwood Beach       122
# 16     Todt Hill-Emerson Hill-Heartland Village-Light...       122
# 21                                           Great Kills       122
# 22                                           Westerleigh       120
# 23            Annadale-Huguenot-Prince's Bay-Eltingville       123
# 24                     New Springville-Bloomfield-Travis       123
# ...

# %%
countNTA = data_NTA_Pdistrict['NTAName'].count()
countNTA
# Out:
# 38789

# %%
data
# Out:
#        INCIDENT_KEY              OCCUR_DATE OCCUR_TIME           BORO  \
# 0         169180023  09/09/2017 12:00:00 AM    3:57:00  STATEN ISLAND
# 1         169180027  09/09/2017 12:00:00 AM   22:15:00          BRONX
# 2         169180025  09/09/2017 12:00:00 AM   18:35:00       BROOKLYN
# 3         169180024  09/09/2017 12:00:00 AM   15:20:00       BROOKLYN
# 4         169180022  09/09/2017 12:00:00 AM    0:20:00       BROOKLYN
# 5         156603440  09/09/2016 12:00:00 AM   20:58:00       BROOKLYN
# 6         156603439  09/09/2016 12:00:00 AM   20:43:00          BRONX
# 7         156603438  09/09/2016 12:00:00 AM   11:50:00      MANHATTAN
# 8         156552658  09/09/2016 12:00:00 AM    0:18:00         QUEENS
# 9         146014287  09/09/2015 12:00:00 AM   23:08:00          BRONX
# 10        146014286  09/09/2015 12:00:00 AM   23:00:00      MANHATTAN
# 11        146013532  09/09/2015 12:00:00 AM   19:03:00       BROOKLYN
# ...

# %%
data_total = data.groupby(['PRECINCT', 'VIC_AGE_GROUP']).size()

# %%
data_total
# Out:
# PRECINCT  VIC_AGE_GROUP
# 1         18-24              6
#           25-44              7
#           45-64              1
#           <18                2
# 5         18-24              8
#           25-44             22
#           45-64              2
#           65+                1
#           <18                6
# 6         18-24              7
#           25-44             11
#           45-64              2
#           UNKNOWN            1
# 7         18-24             25
#           25-44             27
#           45-64              5
#           <18               12
# 9         18-24             35
#           25-44             30
#           45-64              7
#           <18                6
# 10        18-24             15
#           25-44             32
#           45-64              3
#           <18                1
# 13        18-24             11
#           25-44             21
#           45-64              5
#           65+                1
# ...

# %%
data_total_frame = data_total.to_frame()
data_total_frame
# Out:
#                           0
# PRECINCT VIC_AGE_GROUP
# 1        18-24            6
#          25-44            7
#          45-64            1
#          <18              2
# 5        18-24            8
#          25-44           22
#          45-64            2
#          65+              1
#          <18              6
# 6        18-24            7
#          25-44           11
#          45-64            2
#          UNKNOWN          1
# 7        18-24           25
#          25-44           27
#          45-64            5
#          <18             12
# 9        18-24           35
#          25-44           30
#          45-64            7
#          <18              6
# 10       18-24           15
#          25-44           32
#          45-64            3
#          <18              1
# 13       18-24           11
#          25-44           21
#          45-64            5
#          65+              1
#          <18              3
# ...                     ...
# ...

# %%
data_total_frame.to_excel(r'NYC_total_shooting.xlsx')

# %%
data_total_pd_shooting = pd.read_excel('NYC_total_shooting_2.xlsx')

# %%
data_total_pd_shooting
# Out:
#     PRECINCT  TOTAL_SHOOTING
# 0          1              16
# 1          5              39
# 2          6              21
# 3          7              69
# 4          9              78
# 5         10              51
# 6         13              41
# 7         14              26
# 8         17               5
# 9         18              23
# 10        19               6
# 11        20              23
# 12        23             322
# 13        24              73
# 14        25             316
# 15        26             109
# 16        28             234
# 17        30             164
# 18        32             450
# 19        33             164
# 20        34             167
# 21        40             621
# 22        41             359
# 23        42             590
# 24        43             575
# 25        44             693
# 26        45             125
# 27        46             666
# 28        47             692
# 29        48             531
# ..       ...             ...
# ...

# %%
data_total_pd_shooting.to_csv(r'NYC_total_shooting_2.csv')

# %%
data_boro_pd_shoot = data.groupby(['BORO','PRECINCT', 'VIC_AGE_GROUP']).size()

# %%
data_boro_pd_shoot
# Out:
# BORO           PRECINCT  VIC_AGE_GROUP
# BRONX          40        18-24            242
#                          25-44            267
#                          45-64             29
#                          65+                3
#                          <18               80
#                41        18-24            160
#                          25-44            140
#                          45-64             10
#                          65+                3
#                          <18               44
#                          UNKNOWN            2
#                42        18-24            276
#                          25-44            205
#                          45-64             24
#                          65+                1
#                          <18               84
#                43        18-24            263
#                          25-44            214
#                          45-64             27
# ...

# %%
data_boro_frame = data_boro_pd_shoot.to_frame()
data_boro_frame
# Out:
#                                         0
# BORO          PRECINCT VIC_AGE_GROUP
# BRONX         40       18-24          242
#                        25-44          267
#                        45-64           29
#                        65+              3
#                        <18             80
#               41       18-24          160
#                        25-44          140
#                        45-64           10
#                        65+              3
#                        <18             44
#                        UNKNOWN          2
#               42       18-24          276
#                        25-44          205
#                        45-64           24
#                        65+              1
#                        <18             84
#               43       18-24          263
#                        25-44          214
#                        45-64           27
#                        65+              2
# ...

# %%
data_boro_frame.to_excel(r'NYC_boro_pd_shoot_total.xlsx')

# %%
data_total_pd_shooting_boro = pd.read_excel('NYC_total_shooting_3.xlsx')

# %%
data_total_pd_shooting_boro
# Out:
#              BORO  PRECINCT  TOTAL_SHOOTING
# 0       MANHATTEN         1              16
# 1       MANHATTEN         5              39
# 2       MANHATTEN         6              21
# 3       MANHATTEN         7              69
# 4       MANHATTEN         9              78
# 5       MANHATTEN        10              51
# 6       MANHATTEN        13              41
# 7       MANHATTEN        14              26
# 8       MANHATTEN        17               5
# 9       MANHATTEN        18              23
# 10      MANHATTEN        19               6
# 11      MANHATTEN        20              23
# 12      MANHATTEN        23             322
# 13      MANHATTEN        24              73
# 14      MANHATTEN        25             316
# 15      MANHATTEN        26             109
# 16      MANHATTEN        28             234
# 17      MANHATTEN        30             164
# 18      MANHATTEN        32             450
# 19      MANHATTEN        33             164
# ...

# %%
data_total_pd_shooting_boro.to_csv(r'NYC_total_shooting_3.csv')

# %%
data
# Out:
#        INCIDENT_KEY              OCCUR_DATE OCCUR_TIME           BORO  \
# 0         169180023  09/09/2017 12:00:00 AM    3:57:00  STATEN ISLAND
# 1         169180027  09/09/2017 12:00:00 AM   22:15:00          BRONX
# 2         169180025  09/09/2017 12:00:00 AM   18:35:00       BROOKLYN
# 3         169180024  09/09/2017 12:00:00 AM   15:20:00       BROOKLYN
# 4         169180022  09/09/2017 12:00:00 AM    0:20:00       BROOKLYN
# 5         156603440  09/09/2016 12:00:00 AM   20:58:00       BROOKLYN
# 6         156603439  09/09/2016 12:00:00 AM   20:43:00          BRONX
# 7         156603438  09/09/2016 12:00:00 AM   11:50:00      MANHATTAN
# 8         156552658  09/09/2016 12:00:00 AM    0:18:00         QUEENS
# 9         146014287  09/09/2015 12:00:00 AM   23:08:00          BRONX
# 10        146014286  09/09/2015 12:00:00 AM   23:00:00      MANHATTAN
# 11        146013532  09/09/2015 12:00:00 AM   19:03:00       BROOKLYN
# ...

# %%
dataShootingYear = pd.read_csv("victimShootings.csv")

# %%
dataShootingYear.head()
# Out:
#    OCCUR_DATE OCCUR_TIME           BORO  PRECINCT VIC_AGE_GROUP VIC_SEX  \
# 0  2017-09-09    3:57:00  STATEN ISLAND       120         25-44       M
# 1  2017-09-09   22:15:00          BRONX        50         25-44       M
# 2  2017-09-09   18:35:00       BROOKLYN        79         18-24       M
# 3  2017-09-09   15:20:00       BROOKLYN        67         18-24       M
# 4  2017-09-09    0:20:00       BROOKLYN        61         25-44       M
#
#                    VIC_RACE  X_COORD_CD  Y_COORD_CD   Latitude  Longitude  \
# 0                     BLACK      959975      171772  40.638126 -74.087467
# 1            BLACK HISPANIC     1011288      255912  40.869061 -73.902242
# 2                     BLACK      999888      193014  40.696450 -73.943607
# 3                     BLACK      997784      172132  40.639137 -73.951236
# 4  ASIAN / PACIFIC ISLANDER     1001019      156467  40.596134 -73.939619
#
#    Year
# 0  2017
# 1  2017
# 2  2017
# 3  2017
# 4  2017

# %%
datashootyear = dataShootingYear.groupby(['BORO','PRECINCT', 'Year', 'VIC_AGE_GROUP']).size()

# %%
datashootyear
# Out:
# BORO           PRECINCT  Year  VIC_AGE_GROUP
# BRONX          40        2006  18-24            21
#                                25-44            20
#                                45-64             2
#                                <18               6
#                          2007  18-24            19
#                                25-44            27
#                                45-64             4
#                                65+               2
#                                <18               4
#                          2008  18-24            20
#                                25-44            19
#                                45-64             3
#                                <18              12
#                          2009  18-24            21
#                                25-44            41
#                                45-64             1
#                                <18               8
# ...

# %%
datashootframe = datashootyear.to_frame()

# %%
datashootframe
# Out:
#                                             0
# BORO          PRECINCT Year VIC_AGE_GROUP
# BRONX         40       2006 18-24          21
#                             25-44          20
#                             45-64           2
#                             <18             6
#                        2007 18-24          19
#                             25-44          27
#                             45-64           4
#                             65+             2
#                             <18             4
#                        2008 18-24          20
#                             25-44          19
#                             45-64           3
#                             <18            12
#                        2009 18-24          21
#                             25-44          41
#                             45-64           1
#                             <18             8
#                        2010 18-24          31
# ...

# %%
datashootframe.to_excel(r'NYC_boro_pd_year_shoot.xlsx')

# %%
data
# Out:
#        INCIDENT_KEY              OCCUR_DATE OCCUR_TIME           BORO  \
# 0         169180023  09/09/2017 12:00:00 AM    3:57:00  STATEN ISLAND
# 1         169180027  09/09/2017 12:00:00 AM   22:15:00          BRONX
# 2         169180025  09/09/2017 12:00:00 AM   18:35:00       BROOKLYN
# 3         169180024  09/09/2017 12:00:00 AM   15:20:00       BROOKLYN
# 4         169180022  09/09/2017 12:00:00 AM    0:20:00       BROOKLYN
# 5         156603440  09/09/2016 12:00:00 AM   20:58:00       BROOKLYN
# 6         156603439  09/09/2016 12:00:00 AM   20:43:00          BRONX
# 7         156603438  09/09/2016 12:00:00 AM   11:50:00      MANHATTAN
# 8         156552658  09/09/2016 12:00:00 AM    0:18:00         QUEENS
# 9         146014287  09/09/2015 12:00:00 AM   23:08:00          BRONX
# 10        146014286  09/09/2015 12:00:00 AM   23:00:00      MANHATTAN
# 11        146013532  09/09/2015 12:00:00 AM   19:03:00       BROOKLYN
# ...

# %%
datadata = pd.read_csv("NYPD_Shooting_Incident_Data.csv")

# %%
datadata
# Out:
#        INCIDENT_KEY  OCCUR_DATE OCCUR_TIME           BORO  PRECINCT  \
# 0         191703454  12/31/2018   21:45:00          BRONX        47
# 1         191698518  12/31/2018   16:56:00      MANHATTAN         6
# 2         191681602  12/30/2018    3:12:00         QUEENS       114
# 3         191681601  12/30/2018    2:22:00       BROOKLYN        75
# 4         191681604  12/30/2018   15:10:00       BROOKLYN        77
# 5         191681600  12/28/2018   22:07:00          BRONX        42
# 6         191681185  12/28/2018   21:52:00          BRONX        40
# 7         191681603  12/28/2018   23:54:00       BROOKLYN        69
# 8         191681599  12/28/2018   23:01:00         QUEENS       113
# 9         191681185  12/28/2018   21:52:00          BRONX        40
# 10        191557604  12/26/2018   17:37:00         QUEENS       103
# 11        191557605  12/26/2018   16:16:00      MANHATTAN        23
# 12        191558082  12/26/2018   19:23:00      MANHATTAN        25
# ...

# %%
data_total2 = datadata.groupby(['BORO', 'PRECINCT', 'VIC_AGE_GROUP']).size()

# %%
data_total2
# Out:
# BORO           PRECINCT  VIC_AGE_GROUP
# BRONX          40        18-24            254
#                          25-44            286
#                          45-64             32
#                          65+                3
#                          <18               85
#                41        18-24            166
#                          25-44            148
#                          45-64             10
#                          65+                3
#                          <18               45
#                          UNKNOWN            2
#                42        18-24            286
#                          25-44            226
#                          45-64             26
#                          65+                1
#                          <18               88
#                43        18-24            274
#                          25-44            225
#                          45-64             31
# ...

# %%
data_boro_pd_frame = data_total2.to_frame()

# %%
data_boro_pd_frame
# Out:
#                                         0
# BORO          PRECINCT VIC_AGE_GROUP
# BRONX         40       18-24          254
#                        25-44          286
#                        45-64           32
#                        65+              3
#                        <18             85
#               41       18-24          166
#                        25-44          148
#                        45-64           10
#                        65+              3
#                        <18             45
#                        UNKNOWN          2
#               42       18-24          286
#                        25-44          226
#                        45-64           26
#                        65+              1
#                        <18             88
#               43       18-24          274
#                        25-44          225
#                        45-64           31
#                        65+              2
# ...

# %%
#data_boro_pd_frame.to_excel(r'NYC_boro_pd_shoot_total2.xlsx')

# %%
data_total_pd_shooting_boro2 = pd.read_excel('NYC_boro_pd_shoot_total3.xlsx')

# %%
data_total_pd_shooting_boro2.to_csv(r'NYC_boro_pd_shoot_total3_3.csv')

# %%
dataShootingYear = pd.read_csv("victimShootings.csv")

# %%
dataShootingYear
# Out:
#        OCCUR_DATE OCCUR_TIME           BORO  PRECINCT VIC_AGE_GROUP VIC_SEX  \
# 0      2018-12-31   21:45:00          BRONX        47         25-44       M
# 1      2018-12-31   16:56:00      MANHATTAN         6         45-64       M
# 2      2018-12-30    3:12:00         QUEENS       114         25-44       M
# 3      2018-12-30    2:22:00       BROOKLYN        75         25-44       M
# 4      2018-12-30   15:10:00       BROOKLYN        77         18-24       M
# 5      2018-12-28   22:07:00          BRONX        42         25-44       M
# 6      2018-12-28   21:52:00          BRONX        40         45-64       M
# 7      2018-12-28   23:54:00       BROOKLYN        69         18-24       M
# 8      2018-12-28   23:01:00         QUEENS       113         45-64       M
# 9      2018-12-28   21:52:00          BRONX        40         18-24       M
# 10     2018-12-26   17:37:00         QUEENS       103         45-64       M
# ...

# %%
datashootyear = dataShootingYear.groupby(['BORO','PRECINCT', 'Year', 'VIC_AGE_GROUP']).size()

# %%
datashootyear
# Out:
# BORO           PRECINCT  Year  VIC_AGE_GROUP
# BRONX          40        2006  18-24            21
#                                25-44            20
#                                45-64             2
#                                <18               6
#                          2007  18-24            19
#                                25-44            27
#                                45-64             4
#                                65+               2
#                                <18               4
#                          2008  18-24            20
#                                25-44            19
#                                45-64             3
#                                <18              12
#                          2009  18-24            21
#                                25-44            41
#                                45-64             1
#                                <18               8
# ...

# %%
datashootyearframe = datashootyear.to_frame()

# %%
datashootyearframe.to_excel(r'NYC_boro_pd_year_shoot2.xlsx')

# %%
data_total_pd_shooting_boro_year = pd.read_excel("NYC_boro_pd_year_shoot3.xlsx")
data_total_pd_shooting_boro_year
# Out:
#               BORO  PRECINCT  YEAR  TOTAL_SHOOTING
# 0            BRONX        40  2006              49
# 1            BRONX        40  2007              56
# 2            BRONX        40  2008              54
# 3            BRONX        40  2009              71
# 4            BRONX        40  2010              67
# 5            BRONX        40  2011              87
# 6            BRONX        40  2012              59
# 7            BRONX        40  2013              38
# 8            BRONX        40  2014              42
# 9            BRONX        40  2015              32
# 10           BRONX        40  2016              34
# 11           BRONX        40  2017              32
# 12           BRONX        40  2018              39
# 13           BRONX        41  2006              36
# 14           BRONX        41  2007              41
# 15           BRONX        41  2008              33
# 16           BRONX        41  2009              31
# ...

# %%
data_total_pd_shooting_boro_year.to_csv(r'NYC_boro_pd_year_shoot_total.csv')

# %%
data_total_pd_shooting_boro_year2 = pd.read_excel("NYC_boro_pd_year_shoot4.xlsx")
data_total_pd_shooting_boro_year2
# Out:
#               BORO  PRECINCT  YEAR  TOTAL_SHOOTING
# 0        MANHATTEN         1  2007               1
# 1        MANHATTEN         1  2008               1
# 2        MANHATTEN         1  2009               1
# 3        MANHATTEN         1  2010               7
# 4        MANHATTEN         1  2012               2
# 5        MANHATTEN         1  2013               1
# 6        MANHATTEN         1  2015               1
# 7        MANHATTEN         1  2017               2
# 8        MANHATTEN         5  2006               3
# 9        MANHATTEN         5  2008              14
# 10       MANHATTEN         5  2009               3
# 11       MANHATTEN         5  2010               1
# 12       MANHATTEN         5  2011               1
# 13       MANHATTEN         5  2012               7
# 14       MANHATTEN         5  2013               2
# 15       MANHATTEN         5  2014               3
# 16       MANHATTEN         5  2015               5
# ...

# %%
data_total_pd_shooting_boro_year2.to_csv(r'NYC_boro_pd_year_shoot_total_FINAL.csv')

# %%
ffg = pd.read_csv("NYC_boro_pd_shoot_total3_3.csv")

# %%
fgfhh = ffg['PRECINCT'] 
fgfhh
# Out:
# 0       1
# 1       5
# 2       6
# 3       7
# 4       9
# 5      10
# 6      13
# 7      14
# 8      17
# 9      18
# 10     19
# 11     20
# 12     23
# 13     24
# 14     25
# 15     26
# 16     28
# 17     30
# 18     32
# 19     33
# 20     34
# 21     40
# 22     41
# 23     42
# 24     43
# 25     44
# 26     45
# 27     46
# 28     47
# 29     48
#      ...
# 46     76
# 47     77
# 48     78
# 49     79
# 50     81
# 51     83
# 52     84
# 53     88
# 54     90
# 55     94
# 56    100
# 57    101
# 58    102
# 59    103
# 60    104
# 61    105
# 62    106
# 63    107
# 64    108
# 65    109
# 66    110
# 67    111
# 68    112
# 69    113
# 70    114
# 71    115
# 72    120
# 73    121
# 74    122
# 75    123
# Name: PRECINCT, Length: 76, dtype: int64

# %%
rggg = fgfhh.to_frame()

# %%
rggg.to_csv(r'NYC_boro_pd_shoot_total3_4.csv')
